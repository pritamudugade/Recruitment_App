# %%
import pandas as pd

# %%
df = pd.read_csv("/content/candidates.csv")

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Designation', 'Domain', 'Experience (years)',
#        'Expertise', 'Specialization', 'Tools Used', 'Education', 'Languages',
#        'Certifications', 'Email', 'Phone Number', 'Work History', 'Location'],
#       dtype='object')

# %%
df.head().T
# Out:
#                                                                     0  \
# Name                                                     Devin Horton
# Age                                                                41
# Designation                                         Software Engineer
# Domain                                                     Healthcare
# Experience (years)                                                  8
# Expertise           ['Data Analysis', 'Sales', 'Python', 'Machine ...
# Specialization                                      Digital Marketing
# Tools Used          ['Python', 'SQL', 'AWS', 'GitHub', 'Adobe Phot...
# Education                                           Bachelor's Degree
# Languages           ['German', 'English', 'Spanish', 'Chinese', 'F...
# Certifications              ['CISSP', 'PMP', 'AWS Certified', 'CCNA']
# Email                                              gary19@example.net
# ...

# %%
df.Name == "Emily Perry"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: Name, Length: 500, dtype: bool
